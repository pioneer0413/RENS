# %%
import numpy as np

import torch

import os
import sys
path_root = '/home/hwkang/jupyter/root' # Change before append.
sys.path.append(os.path.join(path_root, 'utility/')) 

from synthesization import *

# %%
### 테스트용 텐서 및 넘파이배열 생성
t = torch.rand(size=(3,3,3))
n = np.random.rand(3,3,3)
##*

# %%
### 텐서에 대해 검증
t1 = generate_gaussian(t, 0.5)

t2 = generate_salt_and_pepper(t, 0.5)

t3 = generate_uniform(t, 0.5)

t4 = generate_poisson(t, 0.5)

t5 = generate_noisy_data(t, 0.5, 'gaussian')
##*

# %%
### 넘파이배열에 대해 검증
n1 = generate_gaussian(n, 0.5)

n2 = generate_salt_and_pepper(n, 0.5)

n3 = generate_uniform(n, 0.5)

n4 = generate_poisson(n, 0.5)

n5 = generate_noisy_data(n, 0.5, 'gaussian')
##*

# %%
### 결과 확인
print('Tensor')
print(t1, t2, t3, t4, t5)
print()
print('ndarray')
print(n1, n2, n3, n4, n5)
##*
# Out:
# Tensor
# tensor([[[ 1.2248, -0.2960, -0.4676],
#          [-0.5486,  0.4235,  1.2787],
#          [ 0.8047,  0.9820,  0.1184]],
#
#         [[ 1.5406, -0.7410,  0.0087],
#          [ 0.2082,  0.6771,  0.2613],
#          [-0.3084,  0.2142, -0.6996]],
#
#         [[ 0.8512,  0.1910,  1.4279],
#          [ 0.5773,  1.3691,  0.1561],
#          [ 0.3765,  0.2855,  0.4519]]]) tensor([[[0.0612, 0.0612, 0.6094],
#          [0.0612, 0.9169, 0.9169],
#          [0.0612, 0.2898, 0.6537]],
#
#         [[0.0612, 0.0612, 0.9169],
#          [0.4267, 0.9169, 0.5298],
#          [0.0612, 0.9169, 0.1061]],
#
#         [[0.0612, 0.0612, 0.0612],
#          [0.9169, 0.9169, 0.0612],
#          [0.0612, 0.0612, 0.9169]]]) tensor([[[0.5278, 0.5511, 0.7000],
#          [0.6978, 0.5689, 0.9693],
#          [0.7449, 0.7034, 0.8039]],
#
#         [[0.5888, 1.1981, 0.2210],
#          [0.7520, 0.6510, 0.8870],
#          [0.1464, 0.4177, 0.4569]],
#
#         [[0.6160, 0.2232, 0.9870],
# ...
